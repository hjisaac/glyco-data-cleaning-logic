# %% [markdown]
# # Instanovo Training Data Analysis and Preparation

# %%
import os
import sys
import logging
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sys.path.append(
    os.path.abspath(os.path.join(os.getcwd(), os.pardir))
)  # FIXME: Get ride of this


from common.utils import get_ipc_files, get_or_create_folder
from common.logger import get_logger_config
from common.constants import (
    BASE_RAW_DATA_DIR,
    BASE_LOGS_DIR,
    BASE_PLOTS_DIR,
    BASE_REPORTS_CSV_DIR,
)

# %%
target_data = "PXD035158"
artifacts_sub_dir = (BASE_RAW_DATA_DIR / target_data).as_posix().split("/")[-1]
logs_dir = get_or_create_folder(BASE_LOGS_DIR / artifacts_sub_dir)
plots_dir = get_or_create_folder(BASE_PLOTS_DIR / artifacts_sub_dir)
csv_dir = get_or_create_folder(BASE_REPORTS_CSV_DIR / artifacts_sub_dir)

logger_config = get_logger_config(subdir=artifacts_sub_dir)
logging.config.dictConfig(logger_config)
logger = logging.getLogger(__name__)

# %%
logger.info(
    f"Starting with artifacts subdir set to {artifacts_sub_dir}, log_dir set to {logs_dir} and plots_dir set to {plots_dir}"
)
# Out:
# 2025-03-23 15:25:25,527 - __main__ - INFO - Starting with artifacts subdir set to PXD035158, log_dir set to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/logs/PXD035158 and plots_dir set to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/plots/PXD035158

# %%
def save_figure(filename, save_dir=plots_dir):
    """
    Save the current figure to a file.

    Args:
    filename (str): The name of the file to save the figure to.
    save_dir (str): The directory to save the figure in. Defaults to "../reports/plots/{artifacts_sub_dir}".
    """

    extensions = [".png", ".jpg", ".jpeg", ".pdf"]
    name, extension = os.path.splitext(filename)
    # We are defaulting the extension to "pdf"
    extension = extension.lower() if extension else ".pdf"

    if extension not in extensions:
        raise ValueError(
            f"Unknown extension {extension} from {filename}. Please choose one from {extensions}"
        )

    save_path = os.path.join(save_dir, f"{name}{extension}")
    plt.savefig(save_path, format=extension[1:], bbox_inches="tight")
    logger.info(f"Saved plot to {save_path}")

# %%
# Graphing functions go here
def plot_x_y(
    df, index, x_column, y_column, x_label=None, y_label=None, title=None, filename=None
):
    """
    Plot x and y arrays for a given line in the DataFrame using vertical lines.

    Args:
    df (pd.DataFrame): The DataFrame containing the data.
    index (int): The index of the line to plot.
    x_column (str): The name of the x column.
    y_column (str): The name of the y column.
    x_label (str): The label for the x-axis. If None, the x_column name is used.
    y_label (str): The label for the y-axis. If None, the y_column name is used.
    title (str): The title of the plot. If None, a default title is used.
    filename (str): The filename to save the plot. If None, the plot is not saved.
    """
    x_values = df.at[index, x_column]
    y_values = df.at[index, y_column]

    filename = filename or f"{x_column}_vs_{y_column}_for_index_{index}_xy_plot"

    plt.figure(figsize=(10, 6))
    plt.vlines(x_values, ymin=0, ymax=y_values, color="b", alpha=0.7)
    plt.scatter(x_values, y_values, color="b")
    x_label = x_label if x_label else x_column
    y_label = y_label if y_label else y_column
    title = title if title else f"{x_label} vs. {y_label} for index {index}"
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.grid(True, alpha=0.3)
    save_figure(filename)
    plt.show()


def plot_quantitative(df, column, label=None, filename=None):
    """
    Plot histogram and KDE for a quantitative (numeric) column.

    Args:
    df (pd.DataFrame): The DataFrame containing the data.
    column (str): The column to plot.
    label (str): The label to display on the plot. If None, the column name is used.
    """
    label = label if label else column
    filename = filename or (column + "_histogram")
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f"Histogram and KDE for {label}")
    plt.xlabel(label)
    plt.ylabel("Frequency")
    plt.grid(True, alpha=0.2)
    save_figure(filename=filename)
    plt.show()


def plot_qualitative(df, column, label=None, top_n=20, filename=None):
    """
    Plot bar plot for a qualitative (categorical) column.

    Args:
    df (pd.DataFrame): The DataFrame containing the data.
    column (str): The column to plot.
    label (str): The label to display on the plot. If None, the column name is used.
    top_n (int): The number of top values to display.
    """
    label = label if label else column
    filename = filename or (column + "_barplot")
    top_values = df[column].value_counts().nlargest(top_n)
    plt.figure(figsize=(10, 6))
    sns.barplot(y=top_values.index, x=top_values.values)
    plt.title(f"Top {top_n} most frequent values for {label}")
    plt.xlabel("Count")
    plt.ylabel(label)
    plt.grid(True, alpha=0.2)
    save_figure(filename=filename)
    plt.show()

# %%
# Grab all ipc files of interest but ATTENTION;
# loading all many ipc files will increase the computation time
ipc_files = get_ipc_files(BASE_RAW_DATA_DIR / target_data)

# %%
df = pd.concat([pd.read_feather(file) for file in ipc_files], ignore_index=True)
df.head(20)
# Out:
#     index                                           scan  \
# 0    7163  controllerType=0 controllerNumber=1 scan=7164
# 1    7164  controllerType=0 controllerNumber=1 scan=7165
# 2    7166  controllerType=0 controllerNumber=1 scan=7167
# 3    7170  controllerType=0 controllerNumber=1 scan=7171
# 4    7174  controllerType=0 controllerNumber=1 scan=7175
# 5    7179  controllerType=0 controllerNumber=1 scan=7180
# 6    7183  controllerType=0 controllerNumber=1 scan=7184
# 7    7246  controllerType=0 controllerNumber=1 scan=7247
# 8    7376  controllerType=0 controllerNumber=1 scan=7377
# 9    8725  controllerType=0 controllerNumber=1 scan=8726
# 10   8767  controllerType=0 controllerNumber=1 scan=8768
# 11   8768  controllerType=0 controllerNumber=1 scan=8769
# 12   8771  controllerType=0 controllerNumber=1 scan=8772
# 13   8772  controllerType=0 controllerNumber=1 scan=8773
# 14   8788  controllerType=0 controllerNumber=1 scan=8789
# 15   8792  controllerType=0 controllerNumber=1 scan=8793
# 16   8810  controllerType=0 controllerNumber=1 scan=8811
# 17   8813  controllerType=0 controllerNumber=1 scan=8814
# 18   8814  controllerType=0 controllerNumber=1 scan=8815
# 19   8815  controllerType=0 controllerNumber=1 scan=8816
#
#                                                header           rt frag_type  \
# 0   FTMS + c NSI d Full ms2 917.7194@hcd33.00 [120...  1035.362681       HCD
# 1   FTMS + c NSI d Full ms2 785.3360@hcd33.00 [120...  1035.628304       HCD
# 2   FTMS + c NSI d Full ms2 1020.4236@hcd33.00 [12...  1036.086781       HCD
# 3   FTMS + c NSI d Full ms2 973.4209@hcd33.00 [120...  1036.716772       HCD
# 4   FTMS + c NSI d Full ms2 803.0234@hcd33.00 [120...  1037.280757       HCD
# 5   FTMS + c NSI d Full ms2 858.6920@hcd33.00 [120...  1037.954999       HCD
# 6   FTMS + c NSI d Full ms2 1029.0885@hcd33.00 [12...  1038.479256       HCD
# 7   FTMS + c NSI d Full ms2 1047.1151@hcd33.00 [12...  1047.599808       HCD
# 8   FTMS + c NSI d Full ms2 785.5887@hcd33.00 [120...  1066.347446       HCD
# 9   FTMS + c NSI d Full ms2 881.0269@hcd33.00 [120...  1261.293466       HCD
# 10  FTMS + c NSI d Full ms2 782.3209@hcd33.00 [120...  1267.336705       HCD
# 11  FTMS + c NSI d Full ms2 1069.4337@hcd33.00 [12...  1267.602081       HCD
# 12  FTMS + c NSI d Full ms2 1001.7395@hcd33.00 [12...  1268.076313       HCD
# 13  FTMS + c NSI d Full ms2 899.0366@hcd33.00 [120...  1268.209326       HCD
# 14  FTMS + c NSI d Full ms2 1015.4167@hcd33.00 [12...  1270.355646       HCD
# 15  FTMS + c NSI d Full ms2 966.3956@hcd33.00 [120...  1271.096002       HCD
# 16  FTMS + c NSI d Full ms2 965.0625@hcd33.00 [120...  1273.648091       HCD
# 17  FTMS + c NSI d Full ms2 910.7118@hcd33.00 [120...  1274.128068       HCD
# 18  FTMS + c NSI d Full ms2 1029.0892@hcd33.00 [12...  1274.261066       HCD
# 19  FTMS + c NSI d Full ms2 910.7118@hcd20.00 [120...  1274.414710       HCD
#
#     collision_energy  precursor_mz  precursor_charge  precursor_intensity  \
# 0               33.0    917.386108                 3         9.225750e+06
# 1               33.0    785.085449                 4         8.758446e+06
# 2               33.0   1020.089478                 3         4.922692e+06
# 3               33.0    973.087219                 3         4.103132e+06
# 4               33.0    802.689087                 3         1.636536e+06
# 5               33.0    858.357910                 3         1.825259e+06
# 6               33.0   1028.754395                 3         1.170969e+07
# 7               33.0   1046.446899                 3         1.696184e+05
# 8               33.0    785.086670                 4         7.032864e+04
# 9               33.0    880.692810                 3         3.934957e+04
# 10              33.0    782.320862                 3         5.038580e+05
# 11              33.0   1069.099609                 3         3.313959e+05
# 12              33.0   1001.405334                 3         2.774348e+05
# 13              33.0    898.700745                 3         1.187154e+05
# 14              33.0   1015.082336                 3         1.498435e+06
# 15              33.0    966.395630                 3         3.784914e+05
# 16              33.0    964.728394                 3         8.388832e+05
# 17              33.0    910.711792                 3         4.663418e+05
# 18              33.0   1028.755127                 3         4.310227e+05
# 19              20.0    910.711792                 3         1.418946e+07
#
#     lower_offset  ...                        modified_peptide  \
# 0            1.0  ...                        GGPKN[1762]DTEER
# 1            1.0  ...  KKGDSSSGGGGGSSGGGGSSNVGGGSSGGSGSCSSSSR
# 2            1.0  ...                        GGPKN[2070]DTEER
# 3            1.0  ...                          KN[2070]QSSELR
# 4            1.0  ...                          KN[1559]QSSELR
# 5            1.0  ...                    KN[1559]ASNM[147]EYR
# 6            1.0  ...                    KN[2070]ASNM[147]EYR
# 7            1.0  ...  KKGDSSSGGGGGSSGGGGSSNVGGGSSGGSGSCSSSSR
# 8            1.0  ...  KKGDSSSGGGGGSSGGGGSSNVGGGSSGGSGSCSSSSR
# 9            1.0  ...             SVAHN[1493]M[147]TM[147]PNK
# 10           1.0  ...                    KN[1330]ASNM[147]EYR
# 11           1.0  ...                    KN[2191]ASNM[147]EYR
# 12           1.0  ...                    KN[1988]ASNM[147]EYR
# 13           1.0  ...                    KN[1680]ASNM[147]EYR
# 14           1.0  ...                    KN[2029]ASNM[147]EYR
# 15           1.0  ...                    KN[1883]ASNM[147]EYR
# 16           1.0  ...                HM[147]N[1493]ETSHTQGSLR
# 17           1.0  ...                HM[147]N[1330]ETSHTQGSLR
# 18           1.0  ...                    KN[2070]ASNM[147]EYR
# 19           1.0  ...                HM[147]N[1330]ETSHTQGSLR
#
#     peptide_observed_mz peptide_calc_mz delta_mass   expectation hyperscore  \
# 0              917.3861        917.3799     0.0027  1.933290e-09     38.373
# 1              785.0855        785.0808     0.0105  0.000000e+00     97.376
# 2             1020.0895       1020.0836    -0.0010  6.758920e-03     31.962
# 3              973.0872        973.0815     0.0001  7.019999e-03     27.510
# 4              802.6891        802.6848     0.0080  2.104669e-02     25.936
# 5              858.3579        858.3528     0.0045  2.774861e-03     15.926
# 6             1028.7543       1028.7495    -0.0025  3.434939e-04     19.576
# 7             1046.4469       1046.4387    -0.0002  4.397947e-02     10.927
# 8              785.0867        785.0808     0.0087  6.866731e-03     14.153
# 9              880.6928        880.6855     0.0029  4.668943e-02     12.557
# 10             782.3209        782.3159     0.0039  1.465293e-03     23.190
# 11            1069.0996       1069.0917     0.0011  1.047835e-03     24.768
# 12            1001.4054       1001.3984     0.0023  1.336596e-04     19.356
# 13             898.7008        898.6949    -0.0001  3.369582e-02     15.518
# 14            1015.0823       1015.0740    -0.0035  2.697211e-05     30.090
# 15             966.3956        966.3880     0.0036  9.359215e-02     13.561
# 16             964.7284        964.7237    -0.0060  1.521000e-11     37.536
# 17             910.7118        910.7061    -0.0013  0.000000e+00     48.143
# 18            1028.7551       1028.7495    -0.0013  1.456164e-02     18.466
# 19             910.7118        910.7061    -0.0013  4.680885e-02     26.308
#
#    nextscore  probability  auc_intensity                protein
# 0     18.158       1.0000   9.664362e+07  sp|Q62443|NPTX1_MOUSE
# 1     13.117       1.0000   7.440552e+07   sp|Q64012|RALY_MOUSE
# 2     18.467       0.7947   4.561695e+07  sp|Q62443|NPTX1_MOUSE
# 3     17.685       0.9473   3.500579e+07  sp|Q60625|ICAM5_MOUSE
# 4     16.479       0.8262   1.593749e+07  sp|Q60625|ICAM5_MOUSE
# 5     10.560       0.9510   1.279363e+07   sp|P97300|NPTN_MOUSE
# 6     15.023       0.9912   2.989063e+07   sp|P97300|NPTN_MOUSE
# 7      0.000       0.8031   3.325209e+05   sp|Q64012|RALY_MOUSE
# 8      0.000       0.9397   0.000000e+00   sp|Q64012|RALY_MOUSE
# 9      7.683       0.8265   2.468170e+06  sp|P62812|GBRA1_MOUSE
# 10    10.457       0.9745   7.724934e+06   sp|P97300|NPTN_MOUSE
# 11    17.515       0.9708   1.325662e+07   sp|P97300|NPTN_MOUSE
# 12    13.636       0.9737   3.386876e+06   sp|P97300|NPTN_MOUSE
# 13    11.287       0.6397   1.326512e+06   sp|P97300|NPTN_MOUSE
# 14    17.434       0.9982   2.361944e+07   sp|P97300|NPTN_MOUSE
# 15    10.874       0.6159   5.291441e+06   sp|P97300|NPTN_MOUSE
# 16    15.899       1.0000   1.234581e+07  sp|P15209|NTRK2_MOUSE
# 17    15.636       1.0000   1.340278e+08  sp|P15209|NTRK2_MOUSE
# 18    12.935       0.9135   1.270385e+07   sp|P97300|NPTN_MOUSE
# 19    18.425       0.7456   1.340278e+08  sp|P15209|NTRK2_MOUSE
#
# [20 rows x 26 columns]

# %% [markdown]
# ## Columns description
#
# | **Field**               | **Description**                                                                                   |
# |--------------------------|---------------------------------------------------------------------------------------------------|
# | `index`                 | A unique identifier for each entry in the dataset.                                                |
# | `scan`                  | The scan number corresponding to the acquisition of the mass spectrum.                            |
# | `header`                | Additional metadata about the scan, such as file source or retention time.                        |
# | `rt` (Retention Time)   | The time it takes for the peptide to travel through the chromatographic column.                   |
# | `frag_type`             | The type of fragmentation used (e.g., CID, HCD, ETD).                                             |
# | `collision_energy`      | The energy applied to fragment precursor ions.                                                    |
# | `precursor_mz`          | The mass-to-charge ratio (\(m/z\)) of the precursor ion before fragmentation.                     |
# | `precursor_charge`      | The charge state of the precursor ion (e.g., +2, +3).                                             |
# | `precursor_intensity`   | The intensity of the precursor ion signal, reflecting its abundance.                              |
# | `lower_offset`          | The lower bound of the \(m/z\) window for isolating the precursor ion.                            |
# | `upper_offset`          | The upper bound of the \(m/z\) window for isolating the precursor ion.                            |
# | `isolation_target`      | The target \(m/z\) value for isolating the precursor ion.                                         |
# | `mz`                   | The mass-to-charge ratio (\(m/z\)) of ions detected in the spectrum.                              |
# | `intensity`             | The intensity of ions detected in the spectrum, reflecting their abundance.                       |
# | `scale_factor`          | A scaling factor applied to intensities for normalization.                                        |
# | `peptide`               | The sequence of the identified peptide, without modifications.                                    |
# | `modified_peptide`      | The sequence of the peptide with post-translational modifications (e.g., glycosylation).          |
# | `peptide_observed_mz`   | The observed \(m/z\) of the peptide in the spectrum.                                              |
# | `peptide_calc_mz`       | The theoretical \(m/z\) of the peptide based on its sequence and modifications.                   |
# | `delta_mass`            | The difference between observed and calculated mass, indicating potential modifications or errors. |
# | `retention`             | The retention time of the peptide, used for identification confirmation.                          |
# | `expectation`           | A statistical value (e.g., E-value) indicating the reliability of peptide identification.          |
# | `hyperscore`            | A confidence score for peptide identification (e.g., from Mascot or Sequest).                     |
# | `nextscore`             | An additional confidence score for peptide identification.                                        |
# | `probability`           | The probability that the peptide identification is correct.                                       |
# | `auc_intensity`         | The area under the curve (AUC) of the signal intensity, used for quantification.                  |
# | `protein`               | The protein to which the peptide belongs, identified from a database.                             |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312275 entries, 0 to 312274
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                312275 non-null  int64
#  1   scan                 312275 non-null  object
#  2   header               312275 non-null  object
#  3   rt                   312275 non-null  float64
#  4   frag_type            312275 non-null  object
#  5   collision_energy     312275 non-null  float64
#  6   precursor_mz         312275 non-null  float64
#  7   precursor_charge     312275 non-null  int64
#  8   precursor_intensity  312275 non-null  float64
#  9   lower_offset         312275 non-null  float64
#  10  upper_offset         312275 non-null  float64
#  11  isolation_target     263885 non-null  float64
#  12  mz                   312275 non-null  object
#  13  intensity            312275 non-null  object
#  14  scale_factor         312275 non-null  float32
#  15  peptide              312275 non-null  object
#  16  modified_peptide     202234 non-null  object
#  17  peptide_observed_mz  312275 non-null  float64
#  18  peptide_calc_mz      312275 non-null  float64
#  19  delta_mass           312275 non-null  float64
#  20  expectation          312275 non-null  float64
#  21  hyperscore           312275 non-null  float64
#  22  nextscore            312275 non-null  float64
#  23  probability          312275 non-null  float64
#  24  auc_intensity        312275 non-null  float64
#  25  protein              312275 non-null  object
# dtypes: float32(1), float64(15), int64(2), object(8)
# memory usage: 60.8+ MB

# %%
highly_relevant_columns = [
    "peptide",
    "modified_peptide",
    "precursor_mz",
    "precursor_charge",
    "mz",
    "intensity",
    "rt",
    "delta_mass",
    "protein",
]

moderatly_relevant_columns = [
    "scan",
    "header",
    "frag_type",
    "collision_energy",
    "precursor_intensity",
    "peptide_observed_mz",
    "peptide_calc_mz",
    "auc_intensity",
]

less_relevant_columns = [
    "index",
    "lower_offset",
    "upper_offset",
    "isolation_target",
    "scale_factor",
    "expectation",
    "hyperscore",
    "nextscore",
]

# %% [markdown]
# ### Recap statistics for relevant and less relevant columns

# %%
df_described = df[highly_relevant_columns].describe()
df_described.to_csv(csv_dir / "highly_relevant_columns_described_df.csv", index=False)
df_described
# Out:
#         precursor_mz  precursor_charge             rt     delta_mass
# count  312275.000000     312275.000000  312275.000000  312275.000000
# mean     1117.679474          2.921531    8427.788261       0.244578
# std       239.807130          0.741625    3310.433069       0.514800
# min       699.680603          2.000000       6.927878      -1.155900
# 25%       934.766388          2.000000    5892.105705      -0.000600
# 50%      1114.715210          3.000000    8520.580367       0.001600
# 75%      1268.630981          3.000000   11022.939248       0.012900
# max      1998.882324          7.000000   14402.506499       3.191600

# %%
df_described = df[moderatly_relevant_columns].describe()
df_described.to_csv(
    csv_dir / "moderatly_relevant_columns_described_df.csv", index=False
)
df_described
# Out:
#        collision_energy  precursor_intensity  peptide_observed_mz  \
# count     312275.000000         3.122750e+05        312275.000000
# mean          28.557867         1.026321e+07          1117.660569
# std            6.469953         7.873203e+07           239.796809
# min           15.000000         0.000000e+00           699.680600
# 25%           20.000000         1.551230e+06           934.764650
# 50%           33.000000         3.112122e+06          1114.715000
# 75%           33.000000         6.636691e+06          1268.573900
# max           33.000000         7.483633e+09          1998.547800
#
#        peptide_calc_mz  auc_intensity
# count    312275.000000   3.122750e+05
# mean       1117.575224   2.461839e+08
# std         239.775318   2.592035e+09
# min         699.677500   0.000000e+00
# 25%         934.755300   0.000000e+00
# 50%        1114.607300   8.106038e+06
# 75%        1268.566100   6.281992e+07
# max        1997.921400   2.009568e+11

# %%
df_described = df[less_relevant_columns].describe()
df_described.to_csv(csv_dir / "less_relevant_columns_described_df.csv", index=False)
df_described
# Out:
#                index   lower_offset   upper_offset  isolation_target  \
# count  312275.000000  312275.000000  312275.000000     263885.000000
# mean    57147.422115       0.940983       0.940983       1139.965893
# std     22714.123346       0.186757       0.186757        235.068990
# min        46.000000       0.350000       0.350000        700.014709
# 25%     39776.000000       1.000000       1.000000        962.007446
# 50%     57704.000000       1.000000       1.000000       1136.833130
# 75%     75073.000000       1.000000       1.000000       1285.043457
# max    101410.000000       1.000000       1.000000       1999.223877
#
#        scale_factor   expectation     hyperscore      nextscore
# count  3.122750e+05  3.122750e+05  312275.000000  312275.000000
# mean   9.946876e+05  4.589059e-03      42.537462      13.618858
# std    6.233804e+06  4.418408e-02      20.013936       8.389021
# min    8.564084e+03  0.000000e+00       4.422000       0.000000
# 25%    1.389481e+05  0.000000e+00      27.417000      10.159000
# 50%    3.181235e+05  8.010000e-12      39.417000      12.187000
# 75%    6.883350e+05  3.915054e-06      53.574500      14.775000
# max    1.148524e+09  2.140142e+00     219.745000     106.734000

# %%
plot_qualitative(df, "modified_peptide", "Modified peptides")
plot_qualitative(df, "peptide", "Peptide")
plot_qualitative(df, "protein", "Proteins")
# Out:
# 2025-03-23 15:25:37,423 - __main__ - INFO - Saved plot to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/plots/PXD035158/modified_peptide_barplot.pdf
# 2025-03-23 15:25:38,215 - __main__ - INFO - Saved plot to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/plots/PXD035158/peptide_barplot.pdf
# 2025-03-23 15:25:38,826 - __main__ - INFO - Saved plot to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/plots/PXD035158/protein_barplot.pdf

# %%
plot_quantitative(df, "precursor_mz", "Precursor m/z")
plot_quantitative(df, "precursor_charge", "Precursor charge")
plot_quantitative(df, "delta_mass", "Delta mass")
# Out:
# 2025-03-23 15:25:41,351 - __main__ - INFO - Saved plot to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/plots/PXD035158/precursor_mz_histogram.pdf
# 2025-03-23 15:25:43,685 - __main__ - INFO - Saved plot to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/plots/PXD035158/precursor_charge_histogram.pdf
# 2025-03-23 15:26:01,690 - __main__ - INFO - Saved plot to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/plots/PXD035158/delta_mass_histogram.pdf

# %%
peptide_index = 0
plot_x_y(
    df,
    peptide_index,
    "mz",
    "intensity",
    "m/z",
    "Intensity",
    title=f'm/z vs. Intensity for peptide {df.iloc[peptide_index]["peptide"]}',
)
# Out:
# 2025-03-23 15:26:05,345 - __main__ - INFO - Saved plot to /home/hjisaac/AI4Science/instanovo_instadeep/InstanovoGlyco/reports/plots/PXD035158/mz_vs_intensity_for_index_0_xy_plot.pdf

# %% [markdown]
# ## PTMs identification

# %% [markdown]
# The scripts `scripts/identify_ptms` does that helps in identifying ptms.
